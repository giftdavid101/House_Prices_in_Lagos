# %%
import pandas as pd

# %%
data = pd.read_csv("rent_2.csv")
data.head()
# Out:
#    Unnamed: 0     Price    Pid  \
# 0           0    400000  H1190
# 1           1  14000000  G7398
# 2           2    200000  H5843
# 3           3    800000  H1194
# 4           4    300000  H5842
#
#                                        Property_name  \
# 0  1 bedroom mini flat Flat / Apartment for rent ...
# 1  3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2  1 bedroom mini flat Flat / Apartment for rent ...
# 3  2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4  1 bedroom mini flat Flat / Apartment for rent ...
#
#                                          Address Neighboorhood
# 0                 Fidiso Estate Abijo Ajah Lagos          Ajah
# 1        Gerrard Gerrard Gerard Road Ikoyi Lagos         Ikoyi
# 2                        Obadia Akoka Yaba Lagos          Yaba
# 3  surulere Iju Ishaga Road Gbaja Surulere Lagos      Surulere
# 4           Close to Unilag Abule Oja Yaba Lagos          Yaba

# %%
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9853 entries, 0 to 9852
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     9853 non-null   int64
#  1   Price          9853 non-null   int64
#  2   Pid            9853 non-null   object
#  3   Property_name  9853 non-null   object
#  4   Address        9853 non-null   object
#  5   Neighboorhood  9853 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 462.0+ KB

# %%
def data_wrangle(data):

# %%
data["Property_name"].str.replace(" ", "").head()
# Out:
# 0    1bedroomminiflatFlat/ApartmentforrentAbijoAjah...
# 1    3bedroomFlat/ApartmentforrentGerrardGerardroad...
# 2    1bedroomminiflatFlat/ApartmentforrentAkokaYaba...
# 3    2bedroomFlat/ApartmentforrentIjuIshagaRoadGbaj...
# 4    1bedroomminiflatFlat/ApartmentforrentAbule-Oja...
# Name: Property_name, dtype: object
